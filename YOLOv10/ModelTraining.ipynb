# %%
### 1. Mount Google Drive ###

from google.colab import drive

drive.mount('/content/gdrive')

# %%
### 2. Define root directory ###

ROOT_DIR = '/content/gdrive/My Drive/microplastics_augmented'

# %%
### 3. Install Ultralytics ###

# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 993.8/993.8 kB 23.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 52.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 31.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 41.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 19.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 62.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
### 4. Train model ###

import os

from ultralytics import YOLO


# Load a model
model = YOLO("yolov10n.pt")  # load pre trained model

# Use the model
results = model.train(data=os.path.join(ROOT_DIR, "google_colab_config.yaml"), epochs=50)  # train the model
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 118MB/s]
# Ultralytics 8.3.102 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
### 5. Copy results ###

# !scp -r /content/runs '/content/gdrive/My Drive/microplastics_augmented'

# %%
from ultralytics import YOLO
import os

# Load model
model = YOLO("/content/gdrive/My Drive/microplastics_augmented/best.pt")

# Run predictions on test images
results = model.predict(source="/content/gdrive/My Drive/microplastics_augmented/test/images", save=True, conf=0.25)

# This will save the annotated images in 'runs/predict'
# Out:
# image 1/217 /content/gdrive/My Drive/microplastics_augmented/test/images/11_png_jpg.rf.f2508cd160df8602fa7cd798020980b9.jpg: 640x640 3 fibers, 1 film, 1 fragment, 2 pallets, 7.5ms
# image 2/217 /content/gdrive/My Drive/microplastics_augmented/test/images/11_png_jpg.rf.f2508cd160df8602fa7cd798020980b9_flip_h.jpg: 640x640 3 fibers, 1 film, 1 fragment, 1 pallet, 7.5ms
# image 3/217 /content/gdrive/My Drive/microplastics_augmented/test/images/11_png_jpg.rf.f2508cd160df8602fa7cd798020980b9_flip_v.jpg: 640x640 3 fibers, 1 film, 1 fragment, 2 pallets, 43.1ms
# image 4/217 /content/gdrive/My Drive/microplastics_augmented/test/images/11_png_jpg.rf.f2508cd160df8602fa7cd798020980b9_gaussian_noise.jpg: 640x640 2 fibers, 1 film, 2 fragments, 7.5ms
# image 5/217 /content/gdrive/My Drive/microplastics_augmented/test/images/11_png_jpg.rf.f2508cd160df8602fa7cd798020980b9_lighting.jpg: 640x640 3 fibers, 1 film, 1 fragment, 1 pallet, 13.2ms
# ...

# %%
from ultralytics import YOLO

model = YOLO("/content/gdrive/My Drive/microplastics_augmented/best.pt")  # or "last.pt"

metrics = model.val(data="/content/gdrive/My Drive/microplastics_augmented/google_colab_config.yaml", split='test')
# Out:
# Ultralytics 8.3.102 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 3,006,428 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/gdrive/My Drive/microplastics_augmented/test/labels... 217 images, 0 backgrounds, 0 corrupt: 100%|██████████| 217/217 [01:17<00:00,  2.81it/s]
# val: New cache created: /content/gdrive/My Drive/microplastics_augmented/test/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 14/14 [00:07<00:00,  1.95it/s]
#                    all        217       2501      0.961      0.927      0.945      0.652
#                  fiber        217        642      0.968      0.977      0.993      0.936
#                   film        217        643      0.997       0.98      0.986      0.663
#               fragment        217        592      0.953      0.975      0.984      0.641
# ...
